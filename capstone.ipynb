# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("capstone.csv")

# %%
df.head(10)
# Out:
#   PatientID   VisitDate  Age  Gender        City        Department Doctor  \
# 0   P100001  2025-06-18   71    Male       Salem         Neurology  Dr. G
# 1   P100002  2025-12-25    7    Male       Salem          Oncology  Dr. D
# 2   P100003  2025-05-16    8    Male     Madurai        Cardiology  Dr. G
# 3   P100004  2025-09-22   53  Female       Salem       Orthopedics  Dr. E
# 4   P100005  2025-07-13   83    Male      Trichy       Orthopedics  Dr. B
# 5   P100006  2025-01-23   88  Female     Chennai               ENT  Dr. D
# 6   P100007  2025-02-09   46    Male       Salem          Oncology  Dr. F
# 7   P100008  2025-10-04   77  Female  Coimbatore  General Medicine  Dr. E
# 8   P100009  2025-04-18   79    Male     Vellore        Cardiology  Dr. A
# 9   P100010  2025-07-26   59  Female     Vellore         Neurology  Dr. C
#
#   Diagnosis Severity AdmissionType  ...  LabCost  RoomCharges  TotalBill  \
# 0     Fever      Low     Inpatient  ...  5642.96         0.00   13785.10
# ...

# %%
df.tail(10)
# Out:
#      PatientID   VisitDate  Age  Gender        City   Department Doctor  \
# 1990   P101991  2025-09-13   44  Female     Vellore    Neurology  Dr. G
# 1991   P101992  2025-08-09   24    Male     Madurai          ENT  Dr. C
# 1992   P101993  2025-11-04   78    Male       Salem     Oncology  Dr. D
# 1993   P101994  2025-11-12   51    Male      Trichy          ENT  Dr. F
# 1994   P101995  2025-06-21   61  Female     Vellore  Orthopedics  Dr. D
# 1995   P101996  2025-03-25   14  Female     Chennai          ENT  Dr. E
# 1996   P101997  2025-02-16   36    Male  Coimbatore          ENT  Dr. E
# 1997   P101998  2025-02-19   48  Female     Vellore    Neurology  Dr. F
# 1998   P101999  2025-07-28   87  Female     Chennai          ENT  Dr. A
# 1999   P102000  2025-01-24   41    Male       Salem          ENT  Dr. B
#
#      Diagnosis Severity AdmissionType  ...  LabCost  RoomCharges  TotalBill  \
# 1990  Fracture      Low     Emergency  ...  4269.79      2169.06   15216.17
# ...

# %%
df.shape
# Out:
# (2000, 25)

# %%
df.columns
# Out:
# Index(['PatientID', 'VisitDate', 'Age', 'Gender', 'City', 'Department',
#        'Doctor', 'Diagnosis', 'Severity', 'AdmissionType', 'Insurance',
#        'WaitingTime_Min', 'LengthOfStay_Days', 'TreatmentCost', 'MedicineCost',
#        'LabCost', 'RoomCharges', 'TotalBill', 'PaymentMode', 'DischargeStatus',
#        'FollowUpRequired', 'PatientSatisfaction', 'Readmitted30Days',
#        'BloodGroup', 'BMI'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PatientID               object
# VisitDate               object
# Age                      int64
# Gender                  object
# City                    object
# Department              object
# Doctor                  object
# Diagnosis               object
# Severity                object
# AdmissionType           object
# Insurance               object
# WaitingTime_Min          int64
# LengthOfStay_Days        int64
# TreatmentCost          float64
# MedicineCost           float64
# LabCost                float64
# RoomCharges            float64
# TotalBill              float64
# PaymentMode             object
# DischargeStatus         object
# FollowUpRequired        object
# PatientSatisfaction      int64
# Readmitted30Days        object
# BloodGroup              object
# BMI                    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PatientID              0
# VisitDate              0
# Age                    0
# Gender                 0
# City                   0
# Department             0
# Doctor                 0
# Diagnosis              0
# Severity               0
# AdmissionType          0
# Insurance              0
# WaitingTime_Min        0
# LengthOfStay_Days      0
# TreatmentCost          0
# MedicineCost           0
# LabCost                0
# RoomCharges            0
# TotalBill              0
# PaymentMode            0
# DischargeStatus        0
# FollowUpRequired       0
# PatientSatisfaction    0
# Readmitted30Days       0
# BloodGroup             0
# BMI                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Age  WaitingTime_Min  LengthOfStay_Days  TreatmentCost  \
# count  2000.000000      2000.000000        2000.000000    2000.000000
# mean     45.285000        93.613500           4.410500   13977.292535
# std      26.104818        50.567605           3.416259    5386.965108
# min       1.000000         5.000000           0.000000    2175.730000
# 25%      23.000000        52.000000           2.000000   10223.740000
# 50%      45.000000        94.000000           4.000000   13196.615000
# 75%      68.000000       138.000000           6.000000   16947.475000
# max      90.000000       180.000000          12.000000   35653.880000
#
#        MedicineCost     LabCost   RoomCharges     TotalBill  \
# count   2000.000000  2000.00000   2000.000000   2000.000000
# mean    6239.518765  4029.01332   7745.788870  23295.487580
# std     3354.616406  2233.77828   7293.190648   8978.275143
# min      300.750000   212.81000      0.000000   3626.210000
# ...

# %%
df.describe(include='all')
# Out:
#        PatientID   VisitDate          Age Gender   City Department Doctor  \
# count       2000        2000  2000.000000   2000   2000       2000   2000
# unique      2000         363          NaN      2      6          7      8
# top      P100001  2025-09-30          NaN   Male  Salem        ENT  Dr. A
# freq           1          13          NaN   1005    368        303    262
# mean         NaN         NaN    45.285000    NaN    NaN        NaN    NaN
# std          NaN         NaN    26.104818    NaN    NaN        NaN    NaN
# min          NaN         NaN     1.000000    NaN    NaN        NaN    NaN
# 25%          NaN         NaN    23.000000    NaN    NaN        NaN    NaN
# 50%          NaN         NaN    45.000000    NaN    NaN        NaN    NaN
# 75%          NaN         NaN    68.000000    NaN    NaN        NaN    NaN
# max          NaN         NaN    90.000000    NaN    NaN        NaN    NaN
#
#        Diagnosis Severity AdmissionType  ...     LabCost   RoomCharges  \
# ...

# %%
df["TreatmentCost"].mean()
# Out:
# np.float64(13977.292535)

# %%
print("Average Treatment Cost:", df["TreatmentCost"].mean())
# Out:
# Average Treatment Cost: 13977.292535

# %%
print("Average Waiting Time:", df["WaitingTime_Min"].mean())
# Out:
# Average Waiting Time: 93.6135

# %%
print("Average Total Bill:", df["TotalBill"].mean())
# Out:
# Average Total Bill: 23295.48758

# %%
df.groupby("Department")["TotalBill"].mean()
# Out:
# Department
# Cardiology          23753.910034
# ENT                 23808.109670
# General Medicine    23571.296047
# Neurology           21954.643472
# Oncology            23307.106344
# Orthopedics         23629.128644
# Pediatrics          22864.835203
# Name: TotalBill, dtype: float64

# %%
df.groupby("City")["WaitingTime_Min"].mean().round(2)
# Out:
# City
# Chennai       93.10
# Coimbatore    95.11
# Madurai       95.65
# Salem         95.10
# Trichy        91.02
# Vellore       91.51
# Name: WaitingTime_Min, dtype: float64

# %%
df.nlargest(10, "TotalBill")[["PatientID","Department","TotalBill"]]
# Out:
#      PatientID        Department  TotalBill
# 1407   P101408        Cardiology   59423.14
# 216    P100217               ENT   58461.91
# 59     P100060         Neurology   57212.59
# 476    P100477          Oncology   56673.52
# 798    P100799        Pediatrics   55916.61
# 906    P100907        Cardiology   53868.91
# 295    P100296               ENT   53687.63
# 1500   P101501               ENT   52346.05
# 510    P100511  General Medicine   52259.33
# 1260   P101261       Orthopedics   51193.84

# %%
department = df["Department"].value_counts()

plt.figure(figsize=(5,3))
department.plot(kind="bar")
plt.title("Number of Patients by Department")
plt.xlabel("Department")
plt.ylabel("Number of Patients")
plt.show()

# %%
payment = df["PaymentMode"].value_counts()

plt.figure(figsize=(7,7))
payment.plot(kind="pie", autopct="%1.1f%%")
plt.title("Payment Mode Distribution")
plt.ylabel("")
plt.show()

# %%
df["VisitDate"] = pd.to_datetime(df["VisitDate"])

# %%
monthly = df.groupby(df["VisitDate"].dt.to_period("M")).size()

plt.figure(figsize=(10,5))
monthly.plot(kind="line", marker="o")
plt.title("Monthly Patient Visits")
plt.xlabel("Month")
plt.ylabel("Patients")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["TreatmentCost"], df["TotalBill"])
plt.title("Treatment Cost vs Total Bill")
plt.xlabel("Treatment Cost")
plt.ylabel("Total Bill")
plt.show()

# %%
satisfaction = df.groupby("Department")["PatientSatisfaction"].mean()

plt.figure(figsize=(8,5))
satisfaction.plot(kind="bar")
plt.title("Average Patient Satisfaction by Department")
plt.xlabel("Department")
plt.ylabel("Average Satisfaction")
plt.show()
